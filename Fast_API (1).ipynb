# %%
# %%writefile main.py
from fastapi import FastAPI
app= FastAPI()
@app.get("/")
def home():
 return {"message": "My FastAPI project is ready"}
@app.get("/student")
def student():
    return {"name": "Abrar ali",
            "age": 20,
            "course": "Python"}
# Out:
# Overwriting main.py
